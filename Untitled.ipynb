# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
temp_df = pd.read_csv("TemperatureData.csv")

# %%
temp_df.head()
# Out:
#      Stations   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  ...  \
# 0       Dhaka  25.4    28  33.8  36.5  34.6  32.8  31.8  32.5  32.4  ...
# 1  Mymensingh  23.9  26.2  30.4  33.4  33.5  31.5  30.6    31  31.9  ...
# 2     Tangail  23.6  26.3  31.5  36.2  34.4  32.4  31.2  31.6  32.1  ...
# 3    Faridpur    24  27.2    33    37  34.6  32.4    31  31.6  31.5  ...
# 4   Madaripur  24.4  27.8  33.5    36  34.4  32.2  30.5  32.3  31.8  ...
#
#   Mar.1 Apr.1 May.1 Jun.1 Jul.1 Aug.1 Sep.1 Oct.1 Nov.1 Dec.1
# 0  19.3  24.6  26.3  26.9  26.3  26.5  26.3    24  19.9  13.3
# 1  17.6  22.9  25.1    26  25.8  26.1  25.9  23.4  19.5  13.5
# 2  17.7  23.4  25.4  26.2  25.8  26.2    26  23.7  19.2  13.1
# 3  18.6  24.3    26  26.4  25.7  26.3  26.1  24.6  19.7    14
# 4  18.8  23.9  26.2  26.5  26.1  26.4  26.2  24.8  20.7  13.8
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Analyzing Procedure
# * Flip rows and columns
# * Added Year with month
# * Separate Lowest Temperature and Highest Temperature with District Lowest and District Highest
# * plot every district
# * plot every year
# * plot every month

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 25 columns):
# Stations    646 non-null object
# Jan         629 non-null object
# Feb         629 non-null object
# Mar         629 non-null object
# Apr         646 non-null object
# May         629 non-null object
# Jun         646 non-null object
# Jul         629 non-null object
# Aug         629 non-null object
# Sep         629 non-null object
# Oct         629 non-null object
# Nov         629 non-null object
# Dec         629 non-null object
# Jan.1       629 non-null object
# Feb.1       629 non-null object
# Mar.1       629 non-null object
# Apr.1       646 non-null object
# May.1       629 non-null object
# Jun.1       629 non-null object
# Jul.1       629 non-null object
# Aug.1       629 non-null object
# Sep.1       629 non-null object
# Oct.1       629 non-null object
# Nov.1       629 non-null object
# Dec.1       629 non-null object
# dtypes: object(25)
# ...

# %%
for column in temp_df.columns[1:]:
    temp_df[column] = pd.to_numeric(temp_df[column], errors='coerce')

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 25 columns):
# Stations    646 non-null object
# Jan         612 non-null float64
# Feb         612 non-null float64
# Mar         612 non-null float64
# Apr         612 non-null float64
# May         612 non-null float64
# Jun         612 non-null float64
# Jul         612 non-null float64
# Aug         612 non-null float64
# Sep         612 non-null float64
# Oct         612 non-null float64
# Nov         612 non-null float64
# Dec         612 non-null float64
# Jan.1       612 non-null float64
# Feb.1       612 non-null float64
# Mar.1       612 non-null float64
# Apr.1       612 non-null float64
# May.1       612 non-null float64
# Jun.1       612 non-null float64
# Jul.1       612 non-null float64
# Aug.1       612 non-null float64
# Sep.1       612 non-null float64
# Oct.1       612 non-null float64
# Nov.1       612 non-null float64
# Dec.1       612 non-null float64
# ...

# %%
temp_df.plot(figsize=(16,10))

# %%
temp_df.head()
# Out:
#      Stations   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  ...  \
# 0       Dhaka  25.4  28.0  33.8  36.5  34.6  32.8  31.8  32.5  32.4  ...
# 1  Mymensingh  23.9  26.2  30.4  33.4  33.5  31.5  30.6  31.0  31.9  ...
# 2     Tangail  23.6  26.3  31.5  36.2  34.4  32.4  31.2  31.6  32.1  ...
# 3    Faridpur  24.0  27.2  33.0  37.0  34.6  32.4  31.0  31.6  31.5  ...
# 4   Madaripur  24.4  27.8  33.5  36.0  34.4  32.2  30.5  32.3  31.8  ...
#
#    Mar.1  Apr.1  May.1  Jun.1  Jul.1  Aug.1  Sep.1  Oct.1  Nov.1  Dec.1
# 0   19.3   24.6   26.3   26.9   26.3   26.5   26.3   24.0   19.9   13.3
# 1   17.6   22.9   25.1   26.0   25.8   26.1   25.9   23.4   19.5   13.5
# 2   17.7   23.4   25.4   26.2   25.8   26.2   26.0   23.7   19.2   13.1
# 3   18.6   24.3   26.0   26.4   25.7   26.3   26.1   24.6   19.7   14.0
# 4   18.8   23.9   26.2   26.5   26.1   26.4   26.2   24.8   20.7   13.8
#
# [5 rows x 25 columns]

# %%
transpose_df = temp_df.T

# %%
transpose_df
# Out:
#             0           1        2         3          4           5    \
# Stations  Dhaka  Mymensingh  Tangail  Faridpur  Madaripur  Chittagong
# Jan        25.4        23.9     23.6        24       24.4          26
# Feb          28        26.2     26.3      27.2       27.8        27.7
# Mar        33.8        30.4     31.5        33       33.5          32
# Apr        36.5        33.4     36.2        37         36        32.8
# May        34.6        33.5     34.4      34.6       34.4        33.1
# Jun        32.8        31.5     32.4      32.4       32.2        32.3
# Jul        31.8        30.6     31.2        31       30.5        31.2
# Aug        32.5          31     31.6      31.6       32.3        31.7
# Sep        32.4        31.9     32.1      31.5       31.8        31.9
# Oct        32.8        32.2     31.9      31.7       32.5        32.6
# Nov        29.8          29     28.9      28.6         29        29.2
# ...

# %%
transpose_df.plot()
